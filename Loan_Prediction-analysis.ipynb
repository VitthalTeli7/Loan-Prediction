# %% [markdown]
# **Loan Prediction Analysis**

# %% [markdown]
# $Basic$ $Operations$

# %%
# Import the Packages
# Read the data

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


path=r"C:\Users\hp\Documents\DATA-SCIENCE\Data files\loan_prediction.csv"
loan_df=pd.read_csv(path)    # Read the Data 

loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.replace({"3+":"4"})
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['Dependents'].replace({"3+":"4"},inplace=True)

# %%
loan_df.head()   # first 5 rows
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_df.tail()  # it gives last 5 rows
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes          4  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.shape

print("number of rows: ",loan_df.shape[0])
print("number of columns: ",loan_df.shape[1])
# it gives of number of rows and column of the data
# Out:
# number of rows:  614
# number of columns:  13

# %%
loan_df.size

# How many indices are there provided by size
# Out:
# 7982

# %%
loan_df.columns  # All the columns values
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
type(loan_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(loan_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $dtypes$

# %%
loan_df.dtypes

# object means categorical
# other then object numerical(int/float)
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
type(loan_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
loan_df.index
# Out:
# RangeIndex(start=0, stop=614, step=1)

# %%
loan_df.values
# it gives total values of of all columns and rows
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 'Y'],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 'N'],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 'N']],
#       dtype=object)

# %% [markdown]
# **Separate categorical and numerical**
#
# $Method-1$

# %%
d=dict(loan_df.dtypes)
cat=[]
num=[]
for i in d:
    if d[i]=='object':
        cat.append(i)
    else:
        num.append(i)
        
print(f"categorical: {cat}")
print(f"numerical: {num}")
# Out:
# categorical: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# numerical: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %% [markdown]
# $Method-2$

# %%
d1=dict(loan_df.dtypes)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']
cat,num
# Out:
# (['Loan_ID',
#   'Gender',
#   'Married',
#   'Dependents',
#   'Education',
#   'Self_Employed',
#   'Property_Area',
#   'Loan_Status'],
#  ['ApplicantIncome',
#   'CoapplicantIncome',
#   'LoanAmount',
#   'Loan_Amount_Term',
#   'Credit_History'])

# %%
loan_df.select_dtypes(include='object').columns

# Categorical data
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.select_dtypes(exclude='object').columns

# Numerical data
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %% [markdown]
# $isnull$

# %% [markdown]
# - identify if data has any missing values or Null values

# %%
loan_df.isnull()
# False means (no) there is no null value
# True means (yes) there is a null value
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_df.isnull().sum() # total missing values in each columns
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# $Drop-duplicate$
#
# - Drop duplicate values

# %%
loan_df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# $take$ $iloc$ $loc$

# %%
loan_df.take([1,4,5])  # use for select a perticular rows
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 1  LP001003   Male     Yes          1  Graduate            No
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y

# %%
loan_df.take([100,110,120]).take([2,3,5],axis=1)
# Out:
#     Married Dependents Self_Employed
# 100     Yes          2            No
# 110      No          0            No
# 120     Yes        NaN            No

# %% [markdown]
# $iloc-loc$

# %%
loan_df.iloc[10:20,2:5]
# a particular range of rows and columns
# Out:
#    Married Dependents     Education
# 10     Yes          2      Graduate
# 11     Yes          2      Graduate
# 12     Yes          2      Graduate
# 13      No          0      Graduate
# 14     Yes          2      Graduate
# 15      No          0      Graduate
# 16      No          1  Not Graduate
# 17      No          0      Graduate
# 18     Yes          0  Not Graduate
# 19     Yes          0      Graduate

# %%
loan_df.loc[10:20,['Education','Married']] # loc will consider directly column name
# Out:
#        Education Married
# 10      Graduate     Yes
# 11      Graduate     Yes
# 12      Graduate     Yes
# 13      Graduate      No
# 14      Graduate     Yes
# 15      Graduate      No
# 16  Not Graduate      No
# 17      Graduate      No
# 18  Not Graduate     Yes
# 19      Graduate     Yes
# 20  Not Graduate     Yes

# %% [markdown]
# **Categorical Data Analysis**

# %% [markdown]
# *How to read a column*

# %%
loan_df.columns   # all the column names
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df['Education']  #  series and Reading a specific column
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %%
loan_df[['Education','Self_Employed']]  # DataFrame and read more column
# Out:
#         Education Self_Employed
# 0        Graduate            No
# 1        Graduate            No
# 2        Graduate           Yes
# 3    Not Graduate            No
# 4        Graduate            No
# ..            ...           ...
# 609      Graduate            No
# 610      Graduate            No
# 611      Graduate            No
# 612      Graduate            No
# 613      Graduate           Yes
#
# [614 rows x 2 columns]

# %%
loan_df.values
# list of all the observations
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 'Y'],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 'N'],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 'N']],
#       dtype=object)

# %% [markdown]
# **Unique**

# %%
loan_df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
# Python basic logic
set(loan_df['Property_Area'])
# Out:
# {'Rural', 'Semiurban', 'Urban'}

# %% [markdown]
# **NUnique**

# %%
loan_df['Property_Area'].nunique()  # number of values
# Out:
# 3

# %% [markdown]
# **Value_counts**

# %%
loan_df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
#Python skill based

unique_label=loan_df['Property_Area'].unique()
for i in unique_label:
    con=loan_df['Property_Area']==i
    print(i,":",len(loan_df[con]))
# Out:
# Urban : 202
# Rural : 179
# Semiurban : 233

# %%
len(loan_df[loan_df['Property_Area']=='Semiurban'])
# Out:
# 233

# %%
count=0
for i in loan_df['Property_Area']:
    if i=='Semiurban':
        count=count+1
count
# Out:
# 233

# %% [markdown]
# **Frequency table by own skill**

# %%
unique_labels=loan_df['Property_Area'].unique()
count=[]
for i in unique_labels:
    con=loan_df['Property_Area']==i
    count.append(len(loan_df[con]))
property_df=pd.DataFrame(zip(unique_labels,count),
                        columns=['Property_Area','count'])
property_df
# Out:
#   Property_Area  count
# 0         Urban    202
# 1         Rural    179
# 2     Semiurban    233

# %%
property_vc=loan_df['Property_Area'].value_counts()
property_vc
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
property_vc.keys()
# Out:
# Index(['Semiurban', 'Urban', 'Rural'], dtype='object', name='Property_Area')

# %%
property_vc.values
# Out:
# array([233, 202, 179], dtype=int64)

# %%
property_vc=loan_df['Property_Area'].value_counts()
l1=property_vc.keys()
l2=property_vc.values
property_vc_df=pd.DataFrame(zip(l1,l2),
                           columns=['Property_Area','count'])
property_vc_df
# Out:
#   Property_Area  count
# 0     Semiurban    233
# 1         Urban    202
# 2         Rural    179

# %%
property_vc_df
# Out:
#   Property_Area  count
# 0     Semiurban    233
# 1         Urban    202
# 2         Rural    179

# %%
plt.figure(figsize=(6,3))
plt.bar('Property_Area','count',data=property_vc_df)
plt.title('Property Chart')
plt.xlabel('Property_Area')
plt.ylabel('count')
plt.show()

# %%
l=loan_df['Property_Area'].value_counts().keys()
sns.countplot(data=loan_df,
             x='Property_Area',
             order=l)
plt.xlabel('Property_Area')
plt.ylabel('count')
plt.show()

# %%
loan_df.replace({"3+":"4"})
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
for column in cat[1:]:
    loan_df[column].value_counts()
    Property=loan_df[column].value_counts().keys()
    count=loan_df[column].value_counts().values
    Data=pd.DataFrame(zip(Property,count),columns=[column,'count'])
    Data
    
    plt.figure(figsize=(10,6))
    
    plt.subplot(2,2,1)
    plt.title(f"{column} bar chart")
    plt.bar(column,'count',data=Data)
    
    plt.xlabel(column)
    plt.ylabel('count')
    
    plt.subplot(2,2,2)
    plt.title(f"{column} pie chart")
    plt.pie(x=count,labels=Property,autopct="%0.2f%%")
    
    plt.show()

# %%
plt.figure(figsize=(10,15))
for i, column in enumerate(cat[1:]):
    plt.subplot(4,2,i+1)
    
    ax=sns.countplot(data=loan_df,x=column)
    ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize=(15,15))
for i,column in enumerate(cat[1:]):
    plt.subplot(4,2,i+1)
    loan_df[column].value_counts()
    Property=loan_df[column].value_counts(normalize=True).keys()
    count=loan_df[column].value_counts(normalize=True).values
    Data=pd.DataFrame(zip(Property,count),columns=[column,'Count'])
    n=loan_df[column].nunique()
    l=[0.1 for i in range(n)]
    plt.title(column)
    plt.pie(x=count,labels=Property,autopct='%0.2f%%',shadow=True,radius=1,startangle=90,explode=l)
plt.show()

# %% [markdown]
# **Numerical Data Analysis**

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
d1=dict(loan_df.dtypes)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']
cat,num
# Out:
# (['Loan_ID',
#   'Gender',
#   'Married',
#   'Dependents',
#   'Education',
#   'Self_Employed',
#   'Property_Area',
#   'Loan_Status'],
#  ['ApplicantIncome',
#   'CoapplicantIncome',
#   'LoanAmount',
#   'Loan_Amount_Term',
#   'Credit_History'])

# %% [markdown]
# **Statical Measurement**

# %% [markdown]
# - count
# - mean
# - std
# - min
# - 25%
# - 50%
# - 75%
# - max

# %%
dict1={}
count=round(loan_df['CoapplicantIncome'].count(),2)
Max=round(loan_df['CoapplicantIncome'].max(),2)
Min=round(loan_df['CoapplicantIncome'].min(),2)
mean=round(loan_df['CoapplicantIncome'].mean(),2)
median=round(loan_df['CoapplicantIncome'].median(),2)
std=round(loan_df['CoapplicantIncome'].std(),2)
list1=[count,Max,Min,mean,median,std]
dict1['CoapplicantIncome']=list1
dict1
pd.DataFrame(dict1,index=['count','Max','Min','mean','median','std'])
# Out:
#         CoapplicantIncome
# count              614.00
# Max              41667.00
# Min                  0.00
# mean              1621.25
# median            1188.50
# std               2926.25

# %%
dtypes=dict(loan_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)
dict1={}
for i in num:
    count=round(loan_df['CoapplicantIncome'].count(),2)
    Max=round(loan_df['CoapplicantIncome'].max(),2)
    Min=round(loan_df['CoapplicantIncome'].min(),2)
    mean=round(loan_df['CoapplicantIncome'].mean(),2)
    median=round(loan_df['CoapplicantIncome'].median(),2)
    std=round(loan_df['CoapplicantIncome'].std(),2)
    list1=[count,Max,Min,mean,median,std]
    dict1[i]=list1
df=pd.DataFrame(dict1,index=['count','Max','Min','mean','median','std'])
df
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count            614.00             614.00      614.00            614.00
# Max            41667.00           41667.00    41667.00          41667.00
# Min                0.00               0.00        0.00              0.00
# mean            1621.25            1621.25     1621.25           1621.25
# median          1188.50            1188.50     1188.50           1188.50
# std             2926.25            2926.25     2926.25           2926.25
#
#         Credit_History
# count           614.00
# Max           41667.00
# Min               0.00
# mean           1621.25
# median         1188.50
# std            2926.25

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# **Percentile-Quantile**

# %%
p25=round(np.percentile(loan_df['ApplicantIncome'],25),2)
p50=round(np.percentile(loan_df['ApplicantIncome'],50),2)
p75=round(np.percentile(loan_df['ApplicantIncome'],75),2)
print(p25,p50,p75)
# Out:
# 2877.5 3812.5 5795.0

# %%
Q1=round(np.quantile(loan_df['ApplicantIncome'],0.25),2)
Q2=round(np.quantile(loan_df['ApplicantIncome'],0.50),2)
Q3=round(np.quantile(loan_df['ApplicantIncome'],0.75),2)
print(Q1,Q2,Q3)
# Out:
# 2877.5 3812.5 5795.0

# %% [markdown]
# **Histogram**

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num):
    plt.subplot(4,2,i+1)
    plt.title(column)
    plt.hist(loan_df[column],bins=40)
    
plt.show()

# %% [markdown]
# **Empherical rule**

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
applicantIncome_mean=round(loan_df['ApplicantIncome'].mean(),2)
applicantIncome_std=round(loan_df['ApplicantIncome'].std(),2)
print(applicantIncome_mean,applicantIncome_std)
# Out:
# 5403.46 6109.04

# %%
val_minus_1=round(applicantIncome_mean-1*applicantIncome_std,2)
val_plus_1=round(applicantIncome_mean+1*applicantIncome_std,2)
print(val_minus_1,val_plus_1)
# Out:
# -705.58 11512.5

# %%
val_minus_2=round(applicantIncome_mean-2*applicantIncome_std,2)
val_plus_2=round(applicantIncome_mean+2*applicantIncome_std,2)
print(val_minus_2,val_plus_2)
# Out:
# -6814.62 17621.54

# %%
val_minus_3=round(applicantIncome_mean-3*applicantIncome_std,2)
val_plus_3=round(applicantIncome_mean+3*applicantIncome_std,2)
print(val_minus_3,val_plus_3)
# Out:
# -12923.66 23730.58

# %%
con1=loan_df['ApplicantIncome']>val_minus_1
con2=loan_df['ApplicantIncome']<val_plus_1
len(loan_df[con1&con2])
len(loan_df[con1&con2])/len(loan_df)
# Out:
# 0.9348534201954397

# %%
con1=loan_df['ApplicantIncome']>val_minus_2
con2=loan_df['ApplicantIncome']<val_plus_2
len(loan_df[con1&con2])
len(loan_df[con1&con2])/len(loan_df)
# Out:
# 0.9739413680781759

# %%
con1=loan_df['ApplicantIncome']>val_minus_3
con2=loan_df['ApplicantIncome']<val_plus_3
len(loan_df[con1&con2])
len(loan_df[con1&con2])/len(loan_df)
# Out:
# 0.9869706840390879

# %%
def empirical_analysis(col):
    mu = loan_df[col].mean()
    sigma = loan_df[col].std()
    minus1 = mu - sigma ; plus1 = mu + sigma
    minus2 = mu - (2*sigma) ; plus2 = mu + (2*sigma)
    minus3 = mu - (3*sigma) ; plus3 = mu + (3*sigma)
    x1 = loan_df[(loan_df[col] > minus1) & (loan_df[col] < plus1)]
    x2 = loan_df[(loan_df[col] > minus2) & (loan_df[col] < plus2)]
    x3 = loan_df[(loan_df[col] > minus3) & (loan_df[col] < plus3)]
    return(x1,x2,x3)

# %%
 for i in num:
    x=empirical_analysis(i)
    print(x)
# Out:
# (      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %% [markdown]
# **Boxplot**

# %%
plt.figure(figsize=(15,20))
for i,column in enumerate(num):
    plt.subplot(4,2,i+1)
    plt.title(column)
    plt.boxplot(loan_df[column])
plt.show()

# %%
path=r"C:\Users\hp\Documents\DATA-SCIENCE\Data files\loan_prediction.csv"
loan_df=pd.read_csv(path)    # Read the Data 

loan_df

#####------------- Step-1------###########
Q1=np.percentile(loan_df['LoanAmount'],25)
Q2=np.percentile(loan_df['LoanAmount'],50)
Q3=np.percentile(loan_df['LoanAmount'],75)
#####------------- Step-2------###########
IQR=Q3-Q1
#####------------- Step-3------###########
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
#####------------- Step-4------###########
c1=loan_df['LoanAmount']<lb
c2=loan_df['LoanAmount']>ub
con=c1|c2
#####------------- Step-5------###########
outliers_df=loan_df[con]
outliers_df
#####------------- Step-6------###########
c1=loan_df['LoanAmount']>lb
c2=loan_df['LoanAmount']<ub
con=c1&c2
non_outliers_df=loan_df[c1&c2]
non_outliers_df
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
q1=np.quantile(loan_df['LoanAmount'],0.25)
q2=np.quantile(loan_df['LoanAmount'],0.50)
q3=np.quantile(loan_df['LoanAmount'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=loan_df['LoanAmount']>ub
con2=loan_df['LoanAmount']<lb
outliers_df=loan_df[con1|con2]
outliers_df
#con1|con
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
def median_imputed(col):
    q1=np.quantile(loan_df[col],0.25)
    q2=np.quantile(loan_df[col],0.50)
    q3=np.quantile(loan_df[col],0.75)

    Iqr=q3-q1
    ub=q3+(1.5*Iqr)
    lb=q1-(1.5*Iqr)
    con1=loan_df[col]>ub
    con2=loan_df[col]<lb
    outliers_df=loan_df[con1|con2]
    new_values=[]
    median=round(loan_df[col].median(),2)
    for i in loan_df[col].values:
        if i>ub or i<lb:
            new_values.append(median)
        else:
            new_values.append(i)

    loan_df[f'{col}_imputed'] = new_values

# %%
for i in num:
    median_imputed(i)

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
q1=np.quantile(loan_df['LoanAmount'],0.25)
q2=np.quantile(loan_df['LoanAmount'],0.50)
q3=np.quantile(loan_df['LoanAmount'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=loan_df['LoanAmount']>ub
con2=loan_df['LoanAmount']<lb
outliers_df=loan_df[con1|con2]
outliers_df
#con1|con
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status, ApplicantIncome_imputed, CoapplicantIncome_imputed, LoanAmount_imputed, Loan_Amount_Term_imputed, Credit_History_imputed]
# Index: []

# %%
len(outliers_df),len(loan_df),len(outliers_df)*100/len(loan_df)
# Out:
# (0, 614, 0.0)

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.title('non_outliers data')
plt.hist(non_outliers_df['LoanAmount'])

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['LoanAmount'])

plt.subplot(2,2,3)
plt.title('non_outliers data')
plt.boxplot(non_outliers_df['LoanAmount'])

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['LoanAmount'])
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total number of plots (rows * columns)
total_plots = 10 * 2

# Create a figure and axes for the subplots
fig, axes = plt.subplots(10, 2, figsize=(15, 30))  # 5 rows, 4 columns - Adjust the figsize as needed

# Your existing code with minor modifications
plot_counter = 0  # Initialize a counter for subplot positions

for i in num:
    for j in num:
        if i != j and plot_counter < total_plots:  # Check if plot_counter exceeds total_plots
            ax = axes[plot_counter // 2, plot_counter % 2]  # Get the current subplot
            ax.scatter(loan_df[i], loan_df[j])
            ax.set_title(f'Columns: {i} vs {j}')
            plot_counter += 1  # Increment the plot counter

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
corr1=loan_df.corr(numeric_only=True)
corr1
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
sns.heatmap(corr1)
# Out:
# <Axes: >

# %% [markdown]
# $Standardization$

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
mean=loan_df['LoanAmount'].mean()
mean
# Out:
# 146.41216216216216

# %%
mean=round(loan_df['LoanAmount'].mean(),2)
std=round(loan_df['LoanAmount'].std(),2)

# %%
z_score=(loan_df['LoanAmount']-mean)/std
loan_df['Loan_standardization']=z_score
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_amt=loan_df['LoanAmount']
lamt_mean=loan_df['LoanAmount'].mean()
lamt_std=loan_df['LoanAmount'].std()
Nr=loan_amt-lamt_mean
loan_df['LoanAmount_z']=Nr/lamt_std
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['LoanAmount_z']
# Out:
# 0           NaN
# 1     -0.215127
# 2     -0.939534
# 3     -0.308599
# 4     -0.063236
#          ...
# 609   -0.881114
# 610   -1.243317
# 611    1.245369
# 612    0.474227
# 613   -0.156707
# Name: LoanAmount_z, Length: 614, dtype: float64

# %%
loan_df['LoanAmount'].min(),loan_df['LoanAmount_z'].max()
# Out:
# (9.0, 6.468105368560942)

# %%
loan_df['LoanAmount'].idxmin()
# Out:
# 568

# %%
loan_df['LoanAmount'].idxmax()
# Out:
# 171

# %%
loan_df.iloc[[568,171]]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 568  LP002840  Female      No          0  Graduate            No
# 171  LP001585     NaN     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 568             2378                0.0         9.0             360.0
# 171            51763                0.0       700.0             300.0
#
#      Credit_History Property_Area Loan_Status  Loan_standardization  \
# 568             1.0         Urban           N             -1.605445
# 171             1.0         Urban           Y              6.467928
#
#      LoanAmount_z
# 568     -1.605520
# 171      6.468105

# %%
loan_df[['LoanAmount_z']]
# Out:
#      LoanAmount_z
# 0             NaN
# 1       -0.215127
# 2       -0.939534
# 3       -0.308599
# 4       -0.063236
# ..            ...
# 609     -0.881114
# 610     -1.243317
# 611      1.245369
# 612      0.474227
# 613     -0.156707
#
# [614 rows x 1 columns]

# %%
loan_df['LoanAmount']
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
cols=['LoanAmount','LoanAmount_z']
ids=[568,171]
loan_df[['LoanAmount','LoanAmount_z']].iloc[[568,171]]
loan_df[cols].iloc[ids]
# Out:
#      LoanAmount  LoanAmount_z
# 568         9.0     -1.605520
# 171       700.0      6.468105

# %% [markdown]
# $StandardScaler$

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
loan_df['LoanAmount_ss']=ss.fit_transform(loan_df[['LoanAmount']])
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
cols=['LoanAmount','LoanAmount_z','LoanAmount_ss']
loan_df[cols]
# Out:
#      LoanAmount  LoanAmount_z  LoanAmount_ss
# 0           NaN           NaN            NaN
# 1         128.0     -0.215127      -0.215309
# 2          66.0     -0.939534      -0.940328
# 3         120.0     -0.308599      -0.308860
# 4         141.0     -0.063236      -0.063289
# ..          ...           ...            ...
# 609        71.0     -0.881114      -0.881859
# 610        40.0     -1.243317      -1.244368
# 611       253.0      1.245369       1.246423
# 612       187.0      0.474227       0.474628
# 613       133.0     -0.156707      -0.156840
#
# [614 rows x 3 columns]

# %% [markdown]
# $Normalization$

# %% [markdown]
# $MinMaxScaler$

# %%
path=r"C:\Users\hp\Documents\DATA-SCIENCE\Data files\loan_prediction.csv"
loan_df=pd.read_csv(path)    # Read the Data 
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
path=r"C:\Users\hp\Documents\DATA-SCIENCE\Data files\loan_prediction.csv"
loan_df=pd.read_csv(path)    # Read the Data 
loan_dfl_amt=loan_df['LoanAmount']
lamt_min=loan_df['LoanAmount'].min()
lamt_max=loan_df['LoanAmount'].max()
Nr=l_amt-lamt_min
Dr=l_amt-lamt_min
loan_df['LoanAmount_norm']=Nr/Dr
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['LoanAmount_norm'].min(),loan_df['LoanAmount_norm'].max()
# Out:
# (1.0, 1.0)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
loan_df['LoanAmount']=mms.fit_transform(loan_df[['LoanAmount_norm']])

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
